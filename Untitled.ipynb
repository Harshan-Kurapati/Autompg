# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("auto_mpg/auto-mpg.data" , delim_whitespace=True, header=None)
df.columns = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "car_name"]

print(df.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Since horsepower has a string value "?". so it is considered as object.

# %%
df["horsepower"].replace("?", pd.NA, inplace = True)
df["horsepower"] = pd.to_numeric(df["horsepower"])
df["horsepower"].fillna(df["horsepower"].median(), inplace = True)

# %% [markdown]
# # Boxplot
# To check for outliers

# %%
numerical_cols = df.select_dtypes(include = ['int64', 'float64']).columns

# %%
for i in numerical_cols:
    plt.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize = (10,8))

plt.title("Correlation Matrix")
sns.heatmap(df[numerical_cols].corr(), cmap = "coolwarm", annot = True)
plt.show()

# %% [markdown]
# # Train Test Split

# %%
df_new = df.drop("car_name", axis = 1)

X = df_new.drop("mpg", axis = 1)
y = df["mpg"]
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8, shuffle = True, random_state= 42)


print(f"shape of X_train: {X_train.shape}")
print(f"shape of X_test: {X_test.shape}")
print(f"shape of y_train: {y_train.shape}")
print(f"shape of y_test: {y_test.shape}")
# Out:
# shape of X_train: (318, 7)
# shape of X_test: (80, 7)
# shape of y_train: (318,)
# shape of y_test: (80,)

# %% [markdown]
# # Standardisation

# %%
def standardise(x):
    standardscalar = StandardScaler()
    x = x.copy()
    x.loc[:,:] = standardscalar.fit_transform(x)
    
    return x

X_train_S = standardise(X_train)
X_test_S = standardise(X_test)

# %% [markdown]
# # Linear Regression

# %%
X_train_S["bias"] = 1



theta = np.zeros(X_train_S.shape[1])

alpha = 0.01
Iteration = 500
m = len(X_train_S)  

cost_list = [] 
Ite = []

for i in range(Iteration):
    
    h_theta = np.dot(X_train_S,theta)
    
    cost = (1/(2*m))*(np.sum((h_theta - y_train)**2))
    
    J_theta = (1/m) * (np.dot(X_train_S.transpose(), (h_theta - y_train)))
    
    theta -= alpha*J_theta
    
    cost_list.append(cost)
    Ite.append(i)  
    
    
MSE = (1/m)

# %%
plt.plot(Ite, cost_list)
